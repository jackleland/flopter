# %%
import PyQt5 as qt
import PyQt5.QtWidgets as qtw
import PyQt5.QtGui as qtg
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.append('/home/jleland/Coding/Projects/flopter')
import inputparser as prs

# %%
spice_dir = '/home/jleland/Spice/spice2/'
input_dir = spice_dir + 'bin/inputs/'
input_file = 'baseangledprobe.inp'
inp = prs.InputParser(input_filename='{}{}'.format(input_dir, input_file))

# %%
for k in inp.keys():
    for i in inp[k]:
        print('{}: {}'.format(k, i))
# Out:
# plasma: ksi
# plasma: tau
# plasma: mu
# plasma: p0
# plasma: pl
# plasma: alpha_xz
# plasma: alpha_yz
# geom: ly
# geom: lz
# geom: dy
# geom: dz
# geom: lz_low
# geom: lz_high
# geom: ta
# geom: tc
# geom: tp
# geom: npc
# geom: npts_ratio
# geom: scenario
# geom: automatic_ta
# control: time_diag
# control: relax
# control: psolver
# control: diag_ntimes
# control: dump_period
# control: pot_smoothing
# control: history_ntimes
# control: ang_diag
# control: ang_bin
# control: potdebug
# control: pert_pot_file
# optional: param1
# optional: param2
# optional: param3
# optional: param4
# optional: param5
# mks: mks_n0
# mks: mks_te
# mks: mks_b
# mks: mks_main_ion_q
# mks: mks_main_ion_m
# mks: mks_par1
# mks: mks_par2
# mks: mks_par3
# domaindecomp: no_slices_z
# domaindecomp: no_slices_y
# num_blocks: rectangles
# num_blocks: triangles
# num_blocks: circles
# num_blocks: shape1
# num_blocks: shape2
# num_blocks: shape3
# rectangle0: name
# rectangle0: group
# rectangle0: ylow
# ...

# %%
class Example(qtw.QWidget):
    
    def __init__(self):
        super().__init__()
        
        self.initUI()
        
        
    def initUI(self):
        
        self.setGeometry(300, 300, 300, 220)
        self.setWindowTitle('Icon')
        self.setWindowIcon(qtg.QIcon('web.png'))        
    
        self.show()

# %%
app = qtw.QApplication(sys.argv)
ex = Example()
sys.exit(app.exec_())
